# %%
import pandas as pd
import networkx as nx

# %%
grafo = nx.read_gml('../Dados/Rede/social_undirected_filtered_uberlandia.gml')

# %%
for i in grafo.nodes.data():
    print(i)
# Out:
# ('565580EB8FDD16750497A4565ECDBFF8', {})
# ('5E951582ACEB9E81E5786A28866C49CA', {})
# ('06D76D98F69BEB0590280A4DC7DF762A', {})
# ('BCE396FCD91103EA5F34A75CA2CB30ED', {})
# ('CB9016B4905F230F7342D9F45EC1388B', {})
# ('294FCBC2D0C09FF6F387CA1EF18A25B2', {})
# ('78FE6A121B5BE5D5C64FDD03CB51A8BF', {})
# ('13461BE1EA1695078BDB2ADC8FE3D45F', {})
# ('1E4D99CF7997857A2355E73F244DAD13', {})
# ('13E689D7073CDCAB71575E2CA6116859', {})
# ('F7C45090E84086F4472F8D52146C863B', {})
# ('D184885AAE1DE481088B4D6B893A50E4', {})
# ('F4EA235D2363CBA6C02FADAB0FAE8988', {})
# ('1C22AE0B85B9B032F7FA5A1908CA1A72', {})
# ('A1A46E5906D443B4241550EDEC1DAF31', {})
# ('EF56A9CDC09A82D0F59C92D3AF6789CF', {})
# ('CDC29A75CEF1995C211F6B8F11A3C929', {})
# ('7C37E1FA5A6F88C477ADD914EA4D3001', {})
# ('6BE131E87550F8AA21EB4E322BD700BF', {})
# ('8079D144DB0E5565931211D5987EFEA4', {})
# ('ED87485A1DA7DADC56890E0BEB2488D8', {})
# ('87F963FB62286CDF6E90FB2302FDDA19', {})
# ('F8F63C4524877AA697E3741830527E44', {})
# ...

# %%
len(grafo.nodes())
